# %%
# site_name = 'ROI 3'
# site = [27,96.5] # ROI 3

# site_name = 'ROI 7'
# site = [35.328,99.052]

# site_name = 'ROI 8'
# site = [42.990,107.043]

# site_name = 'ROI 9'
# site = [41.7,104.6]

site_name = 'ROI 10'
site = [49.6,119.4]

d_ahi = []
with open("/home/liwei/Himawari_SGLI/{}_2020_PL.txt".format(site_name), "r") as f:
    for line in f.readlines():
        line = line.strip('\n') 
        if line[0:8] == 'AHI TIME':
            ahi = [line[9:13],line[14:16],line[17:19],line[20:22],line[23:25]]
            
            d_ahi.append("".join(ahi))
with open("/home/liwei/Himawari_SGLI/{}_2021_PL.txt".format(site_name), "r") as f:
    for line in f.readlines():
        line = line.strip('\n') 
        if line[0:8] == 'AHI TIME':
            ahi = [line[9:13],line[14:16],line[17:19],line[20:22],line[23:25]]
            
            d_ahi.append("".join(ahi))

# %%
# Radiance

res = 0.01

u_lat,d_lat = site[0]+0.06,site[0]-0.06
l_lon,r_lon = site[1]-0.06,site[1]+0.06



row_AHI = round((u_lat - d_lat) / res)
col_AHI = round((r_lon - l_lon) / res)

row_u_AHI = round((60 - u_lat)/res)
col_l_AHI = round((l_lon - 85)/res)

def DN2TBB(data):
    LUT=np.loadtxt('/media/liwei/Data/Count2Radiance/vis.03')
    return LUT[data,1]

for date in d_ahi:
    YYYY = date[0:4]
    MM = date[4:6]
    DD = date[6:8]
    HH = date[8:10]
    MIN = date[10:12]
    start_time = T.time()
    time = HH + MIN

    print("start processing {}".format(date))
    # make dir
    folder_original = target+date+'_original/'
    folder_AC = target+date+'_AC/'
    mkdir(folder_original)
    mkdir(folder_AC)
    # Download AHI
    with open('/home/liwei/Downloads/{}.vis.03.fld.geoss'.format(date),'rb') as fp:
        data = np.frombuffer(fp.read(),dtype='>u2').reshape(12000,12000)
        data = DN2TBB(data)        
    AHI_data = data[row_u_AHI:row_u_AHI + row_AHI , col_l_AHI:col_l_AHI + col_AHI]


    AHI_data_file=open(folder_AC+'/'+date+'_'+site_name+'_b04_rad.dat','wb')
    AHI_data.astype('f4').tofile(AHI_data_file)
    AHI_data_file.close()
#                 remove_original_file(folder_original)
    end_time=T.time()
    TIME=end_time-start_time
    print('time: {:.1f} secs, {:.1f} mins,{:.1f} hours'.format(TIME,TIME/60,TIME/3600))
# Out:
# start processing 202007030330
# time: 1.5 secs, 0.0 mins,0.0 hours
# start processing 202007070330
# time: 0.6 secs, 0.0 mins,0.0 hours
# start processing 202007220330
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202008060320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202008100330
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202008250320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202008290330
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202009090320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202009280310
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202010130310
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202011160310
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202012010320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202101120320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202101270320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202102070310
# time: 0.7 secs, 0.0 mins,0.0 hours
# start processing 202102110320
# time: 1.0 secs, 0.0 mins,0.0 hours
# start processing 202102260310
# time: 1.0 secs, 0.0 mins,0.0 hours
# start processing 202103020330
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202103130320
# time: 0.9 secs, 0.0 mins,0.0 hours
# start processing 202103170320
# time: 0.9 secs, 0.0 mins,0.0 hours
# start processing 202103210320
# time: 1.1 secs, 0.0 mins,0.0 hours
# start processing 202104010310
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202104050330
# time: 0.9 secs, 0.0 mins,0.0 hours
# start processing 202104160320
# time: 0.9 secs, 0.0 mins,0.0 hours
# start processing 202104200320
# time: 0.9 secs, 0.0 mins,0.0 hours
# start processing 202104240320
# time: 0.6 secs, 0.0 mins,0.0 hours
# start processing 202105050320
# time: 0.6 secs, 0.0 mins,0.0 hours
# start processing 202105090330
# time: 0.6 secs, 0.0 mins,0.0 hours
# start processing 202105200320
# time: 0.6 secs, 0.0 mins,0.0 hours
# start processing 202105240330
# time: 0.6 secs, 0.0 mins,0.0 hours
# start processing 202105280320
# time: 0.7 secs, 0.0 mins,0.0 hours
# start processing 202106080330
# time: 0.6 secs, 0.0 mins,0.0 hours
# start processing 202106120320
# time: 0.7 secs, 0.0 mins,0.0 hours
# start processing 202106230330
# time: 0.8 secs, 0.0 mins,0.0 hours
# start processing 202106270330
# time: 0.8 secs, 0.0 mins,0.0 hours

# %%
# Radiance

res = 0.005

u_lat,d_lat = site[0]+0.06,site[0]-0.06
l_lon,r_lon = site[1]-0.06,site[1]+0.06


row_AHI = int((u_lat - d_lat) / res)
col_AHI = int((r_lon - l_lon) / res)

row_u_AHI = int((60 - u_lat)/res)
col_l_AHI = int((l_lon - 85)/res)




def DN2TBB(data):
    LUT=np.loadtxt('/media/liwei/Data/Count2Radiance/ext.01')
    return LUT[data,1]

for date in d_ahi:
    YYYY = date[0:4]
    MM = date[4:6]
    DD = date[6:8]
    HH = date[8:10]
    MIN = date[10:12]
    start_time = T.time()
    time = HH + MIN

    print("start processing {}".format(date))
    # make dir
    folder_original = target+date+'_original/'
    folder_AC = target+date+'_AC/'
    mkdir(folder_original)
    mkdir(folder_AC)
    # Download AHI
    with open('/home/liwei/Downloads/{}.ext.01.fld.geoss'.format(date),'rb') as fp:
        data = np.frombuffer(fp.read(),dtype='>u2').reshape(24000,24000)
        data = DN2TBB(data)        
    AHI_data = data[row_u_AHI:row_u_AHI + 24 , col_l_AHI:col_l_AHI + 24]


    AHI_data_file=open(folder_AC+'/'+date+'_'+site_name+'_b03_rad.dat','wb')
    AHI_data.astype('f4').tofile(AHI_data_file)
    AHI_data_file.close()
#                 remove_original_file(folder_original)
    end_time=T.time()
    TIME=end_time-start_time
    print('time: {:.1f} secs, {:.1f} mins,{:.1f} hours'.format(TIME,TIME/60,TIME/3600))
# Out:
# start processing 202007030330
# time: 8.3 secs, 0.1 mins,0.0 hours
# start processing 202007070330
# time: 6.3 secs, 0.1 mins,0.0 hours
# start processing 202007220330
# time: 6.6 secs, 0.1 mins,0.0 hours
# start processing 202008060320
# time: 7.2 secs, 0.1 mins,0.0 hours
# start processing 202008100330
# time: 6.8 secs, 0.1 mins,0.0 hours
# start processing 202008250320
# time: 5.7 secs, 0.1 mins,0.0 hours
# start processing 202008290330
# time: 5.6 secs, 0.1 mins,0.0 hours
# start processing 202009090320
# time: 5.4 secs, 0.1 mins,0.0 hours
# start processing 202009280310
# time: 5.5 secs, 0.1 mins,0.0 hours
# start processing 202010130310
# time: 5.9 secs, 0.1 mins,0.0 hours
# start processing 202011160310
# time: 5.3 secs, 0.1 mins,0.0 hours
# start processing 202012010320
# time: 5.7 secs, 0.1 mins,0.0 hours
# start processing 202101120320
# time: 4.7 secs, 0.1 mins,0.0 hours
# start processing 202101270320
# time: 5.6 secs, 0.1 mins,0.0 hours
# start processing 202102070310
# time: 5.4 secs, 0.1 mins,0.0 hours
# start processing 202102110320
# time: 5.6 secs, 0.1 mins,0.0 hours
# start processing 202102260310
# time: 5.5 secs, 0.1 mins,0.0 hours
# start processing 202103020330
# time: 5.6 secs, 0.1 mins,0.0 hours
# start processing 202103130320
# time: 5.3 secs, 0.1 mins,0.0 hours
# start processing 202103170320
# time: 5.7 secs, 0.1 mins,0.0 hours
# start processing 202103210320
# time: 5.1 secs, 0.1 mins,0.0 hours
# start processing 202104010310
# time: 5.2 secs, 0.1 mins,0.0 hours
# start processing 202104050330
# time: 4.9 secs, 0.1 mins,0.0 hours
# start processing 202104160320
# time: 5.1 secs, 0.1 mins,0.0 hours
# start processing 202104200320
# time: 5.2 secs, 0.1 mins,0.0 hours
# start processing 202104240320
# time: 5.3 secs, 0.1 mins,0.0 hours
# start processing 202105050320
# time: 5.2 secs, 0.1 mins,0.0 hours
# start processing 202105090330
# time: 5.3 secs, 0.1 mins,0.0 hours
# start processing 202105200320
# time: 5.1 secs, 0.1 mins,0.0 hours
# start processing 202105240330
# time: 5.1 secs, 0.1 mins,0.0 hours
# start processing 202105280320
# time: 5.1 secs, 0.1 mins,0.0 hours
# start processing 202106080330
# time: 5.2 secs, 0.1 mins,0.0 hours
# start processing 202106120320
# time: 5.0 secs, 0.1 mins,0.0 hours
# start processing 202106230330
# time: 4.9 secs, 0.1 mins,0.0 hours
# start processing 202106270330
# time: 5.0 secs, 0.1 mins,0.0 hours

# %%
# Reflectance

res = 0.01

u_lat,d_lat = site[0]+0.06,site[0]-0.06
l_lon,r_lon = site[1]-0.06,site[1]+0.06



row_AHI = round((u_lat - d_lat) / res)
col_AHI = round((r_lon - l_lon) / res)

row_u_AHI = round((60 - u_lat)/res)
col_l_AHI = round((l_lon - 85)/res)

def DN2TBB(data):
    LUT=np.loadtxt('/media/liwei/Data/count2tbb_v102/vis.03')
    return LUT[data,1]

for date in d_ahi:
    YYYY = date[0:4]
    MM = date[4:6]
    DD = date[6:8]
    HH = date[8:10]
    MIN = date[10:12]
    start_time = T.time()
    time = HH + MIN

    print("start processing {}".format(date))
    # make dir
    folder_original = target+date+'_original/'
    folder_AC = target+date+'_AC/'
    mkdir(folder_original)
    mkdir(folder_AC)
    # Download AHI
    with open('/home/liwei/Downloads/{}.vis.03.fld.geoss'.format(date),'rb') as fp:
        data = np.frombuffer(fp.read(),dtype='>u2').reshape(12000,12000)
        data = DN2TBB(data)        
    AHI_data = data[row_u_AHI:row_u_AHI + row_AHI , col_l_AHI:col_l_AHI + col_AHI]


    AHI_data_file=open(folder_AC+'/'+date+'_'+site_name+'_b04_toa.dat','wb')
    AHI_data.astype('f4').tofile(AHI_data_file)
    AHI_data_file.close()
#                 remove_original_file(folder_original)
    end_time=T.time()
    TIME=end_time-start_time
    print('time: {:.1f} secs, {:.1f} mins,{:.1f} hours'.format(TIME,TIME/60,TIME/3600))
# Out:
# start processing 202007030330
# time: 0.6 secs, 0.0 mins,0.0 hours
# start processing 202007070330
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202007220330
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202008060320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202008100330
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202008250320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202008290330
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202009090320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202009280310
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202010130310
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202011160310
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202012010320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202101120320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202101270320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202102070310
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202102110320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202102260310
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202103020330
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202103130320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202103170320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202103210320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202104010310
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202104050330
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202104160320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202104200320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202104240320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202105050320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202105090330
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202105200320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202105240330
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202105280320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202106080330
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202106120320
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202106230330
# time: 0.5 secs, 0.0 mins,0.0 hours
# start processing 202106270330
# time: 0.5 secs, 0.0 mins,0.0 hours

# %%
# Radiance

res = 0.005

u_lat,d_lat = site[0]+0.06,site[0]-0.06
l_lon,r_lon = site[1]-0.06,site[1]+0.06


row_AHI = int((u_lat - d_lat) / res)
col_AHI = int((r_lon - l_lon) / res)

row_u_AHI = int((60 - u_lat)/res)
col_l_AHI = int((l_lon - 85)/res)




def DN2TBB(data):
    LUT=np.loadtxt('/media/liwei/Data/count2tbb_v102/ext.01')
    return LUT[data,1]

for date in d_ahi:
    YYYY = date[0:4]
    MM = date[4:6]
    DD = date[6:8]
    HH = date[8:10]
    MIN = date[10:12]
    start_time = T.time()
    time = HH + MIN

    print("start processing {}".format(date))
    # make dir
    folder_original = target+date+'_original/'
    folder_AC = target+date+'_AC/'
    mkdir(folder_original)
    mkdir(folder_AC)
    # Download AHI
    with open('/home/liwei/Downloads/{}.ext.01.fld.geoss'.format(date),'rb') as fp:
        data = np.frombuffer(fp.read(),dtype='>u2').reshape(24000,24000)
        data = DN2TBB(data)        
    AHI_data = data[row_u_AHI:row_u_AHI + 24 , col_l_AHI:col_l_AHI + 24]


    AHI_data_file=open(folder_AC+'/'+date+'_'+site_name+'_b03_toa.dat','wb')
    AHI_data.astype('f4').tofile(AHI_data_file)
    AHI_data_file.close()
#                 remove_original_file(folder_original)
    end_time=T.time()
    TIME=end_time-start_time
    print('time: {:.1f} secs, {:.1f} mins,{:.1f} hours'.format(TIME,TIME/60,TIME/3600))
# Out:
# start processing 202007030330
# time: 8.5 secs, 0.1 mins,0.0 hours
# start processing 202007070330
# time: 5.2 secs, 0.1 mins,0.0 hours
# start processing 202007220330
# time: 6.4 secs, 0.1 mins,0.0 hours
# start processing 202008060320
# time: 7.1 secs, 0.1 mins,0.0 hours
# start processing 202008100330
# time: 6.0 secs, 0.1 mins,0.0 hours
# start processing 202008250320
# time: 7.0 secs, 0.1 mins,0.0 hours
# start processing 202008290330
# time: 5.7 secs, 0.1 mins,0.0 hours
# start processing 202009090320
# time: 6.4 secs, 0.1 mins,0.0 hours
# start processing 202009280310
# time: 6.1 secs, 0.1 mins,0.0 hours
# start processing 202010130310
# time: 6.0 secs, 0.1 mins,0.0 hours
# start processing 202011160310
# time: 5.5 secs, 0.1 mins,0.0 hours
# start processing 202012010320
# time: 6.8 secs, 0.1 mins,0.0 hours
# start processing 202101120320
# time: 5.7 secs, 0.1 mins,0.0 hours
# start processing 202101270320
# time: 6.2 secs, 0.1 mins,0.0 hours
# start processing 202102070310
# time: 5.3 secs, 0.1 mins,0.0 hours
# start processing 202102110320
# time: 5.6 secs, 0.1 mins,0.0 hours
# start processing 202102260310
# time: 5.7 secs, 0.1 mins,0.0 hours
# start processing 202103020330
# time: 6.3 secs, 0.1 mins,0.0 hours
# start processing 202103130320
# time: 5.8 secs, 0.1 mins,0.0 hours
# start processing 202103170320
# time: 6.2 secs, 0.1 mins,0.0 hours
# start processing 202103210320
# time: 5.4 secs, 0.1 mins,0.0 hours
# start processing 202104010310
# time: 5.7 secs, 0.1 mins,0.0 hours
# start processing 202104050330
# time: 5.5 secs, 0.1 mins,0.0 hours
# start processing 202104160320
# time: 6.0 secs, 0.1 mins,0.0 hours
# start processing 202104200320
# time: 4.9 secs, 0.1 mins,0.0 hours
# start processing 202104240320
# time: 6.2 secs, 0.1 mins,0.0 hours
# start processing 202105050320
# time: 5.6 secs, 0.1 mins,0.0 hours
# start processing 202105090330
# time: 5.9 secs, 0.1 mins,0.0 hours
# start processing 202105200320
# time: 5.3 secs, 0.1 mins,0.0 hours
# start processing 202105240330
# time: 5.9 secs, 0.1 mins,0.0 hours
# start processing 202105280320
# time: 5.4 secs, 0.1 mins,0.0 hours
# start processing 202106080330
# time: 5.9 secs, 0.1 mins,0.0 hours
# start processing 202106120320
# time: 5.6 secs, 0.1 mins,0.0 hours
# start processing 202106230330
# time: 5.9 secs, 0.1 mins,0.0 hours
# start processing 202106270330
# time: 5.5 secs, 0.1 mins,0.0 hours
